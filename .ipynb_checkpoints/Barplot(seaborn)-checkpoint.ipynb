# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\LENOVO\Desktop\DATA VISUALIZATION PROJECT\Censi.csv')

# %%
data
# Out:
#                       State/UTs  Population      Male    Female Literacy Rate  \
# 0             JAMMU AND KASHMIR    10143700   5360926   4782774        67.16%
# 1              HIMACHAL PRADESH     6077900   3087940   2989960        82.80%
# 2                        PUNJAB    24358999  12985045  11373954        75.84%
# 3                    CHANDIGARH      900635    506938    393697        86.05%
# 4                   UTTARAKHAND     8489349   4325924   4163425        78.82%
# 5                       HARYANA    21144564  11363953   9780611        75.55%
# 6                  NCT OF DELHI    13850507   7607234   6243273        86.21%
# 7                     RAJASTHAN    56507188  29420011  27087177        66.11%
# 8                 UTTAR PRADESH   166197921  87565369  78632552        67.68%
# 9                         BIHAR    82998509  43243795  39754714        61.80%
# 10                       SIKKIM      540851    288484    252367        81.42%
# ...

# %%
population = data[['State/UTs','Population']].sort_values(by=['Population'],ascending=False).reset_index(drop=True)
plt.figure(figsize=(8,10))
ax =sns.barplot(x='Population',y='State/UTs',data=population)
plt.show()
