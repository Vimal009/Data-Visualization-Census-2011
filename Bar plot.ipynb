# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv(r'C:\Users\LENOVO\Desktop\DATA VISUALIZATION PROJECT\census.csv')

# %%
d
# Out:
#                        State/UT    Population         Male       Female  \
# 0             JAMMU AND KASHMIR   1,01,43,700    53,60,926    47,82,774
# 1              HIMACHAL PRADESH     60,77,900    30,87,940    29,89,960
# 2                        PUNJAB   2,43,58,999  1,29,85,045  1,13,73,954
# 3                    CHANDIGARH      9,00,635     5,06,938     3,93,697
# 4                   UTTARAKHAND     84,89,349    43,25,924    41,63,425
# 5                       HARYANA   2,11,44,564  1,13,63,953    97,80,611
# 6                  NCT OF DELHI   1,38,50,507    76,07,234    62,43,273
# 7                     RAJASTHAN   5,65,07,188  2,94,20,011  2,70,87,177
# 8                 UTTAR PRADESH  16,61,97,921  8,75,65,369  7,86,32,552
# 9                         BIHAR   8,29,98,509  4,32,43,795  3,97,54,714
# 10                       SIKKIM      5,40,851     2,88,484     2,52,367
# 11            ARUNACHAL PRADESH     10,97,968     5,79,941     5,18,027
# ...

# %%
df = d.sort_values(by='Literacy Rate', ascending=False).head()
states = df['State/UT']
ratio = df['Literacy Rate']
plt.bar(states, ratio)
plt.xlabel('State/UT')
plt.ylabel('Literacy Rate')
plt.title('Literate')
print(df.head())
plt.show()
# Out:
#        State/UT   Population         Male       Female Literacy Rate  \
# 31       KERALA  3,18,41,374  1,54,68,614  1,63,72,760        94.00%
# 30  LAKSHADWEEP       60,650       31,131       29,519        91.85%
# 14      MIZORAM     8,88,573     4,59,109     4,29,464        91.33%
# 29          GOA    13,47,668     6,87,248     6,60,420        88.70%
# 15      TRIPURA    31,99,203    16,42,225    15,56,978        87.22%
#
#    Sex Ratio%
# 31      1,037
# 30        946
# 14        976
# 29        973
# 15        960
